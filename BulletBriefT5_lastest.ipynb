# %% [markdown]
# # setup

# %%
# !pip install -q transformers datasets evaluate
# !pip install -q tokenizers
# !pip install -q --upgrade accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 109.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 49.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 130.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 20.9 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for sns (setup.py) ... done

# %%
import pandas as pd
import numpy as np
import torch

# %% [markdown]
# # dataset

# %%
data_mix1 = pd.read_csv('complete_data_mix1.csv')
data_mix2 = pd.read_csv('complete_data_mix2.csv')
data = pd.concat([data_mix1, data_mix2], axis=0)
data.head()
# Out:
#                                                  sub  \
# 0  - In a perfect world, the relationship between...
# 1  This is my first narrative feature. It's calle...
# 2  The emotional affair, as opposed to the physic...
# 3  - You might think that 'collective illusions' ...
# 4  There’s 21 strategies in habit change and they...
#
#                                              summary
# 0  - Public opinion should reflect individual pri...
# 1  - First narrative feature called Every Secret ...
# 2  - Emotional affair is being emotionally invest...
# 3  - Collective illusions harm social trust\n- On...
# 4  - There are 21 strategies for habit change\n- ...

# %%
from datasets import Dataset
custom_dataset = Dataset.from_pandas(data)
custom_dataset
# Out:
# Dataset({
#     features: ['sub', 'summary', '__index_level_0__'],
#     num_rows: 4138
# })

# %% [markdown]
# # Preprocessing

# %%
from transformers import AutoTokenizer
checkpoint = "t5-base"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
    prefix = "summarize: "
    inputs = [prefix + doc for doc in examples["sub"]]
    model_inputs = tokenizer(inputs, max_length=4096, truncation=True)
    labels = tokenizer(examples["summary"], max_length=2048, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
custom_dataset[0]
# Out:
# {'sub': "- In a perfect world, the relationship between private opinion and public opinion would be basically like a mirror. At its best, public opinion holds a mirror to us, and it reflects exactly who we are. What 'collective illusions' do to that relationship is turn it into a funhouse of mirrors. You're still seeing yourself, but it is distorted in ways that make it almost unrecognizable. A collective illusion is a situation where most people in a group go along with an idea that they don't agree with, simply because they incorrectly believe that most people in the group agree with it. The majority of people in a group believe the majority thinks something that they don't. They lead individuals to make decisions that are contrary to their private values. And as a result, the entire group can end up doing something that almost nobody wants, which is fatal to free society. My think tank, Populace, studies collective illusions, and uses what we call 'private opinion methods,' which are just methods that help reveal people's private views, free of social pressure and other distorting influences on public opinion. And every question we ever ask, we always ask what the individual thinks, and what they believe most people would say to that question. And that combination of methods helps surface collective illusions all across society. We have found them almost everywhere we look- from the kind of lives we want to live, to the country we want to live in, to the way we want to treat each other. And even what we expect out of our institutions from education to the workplace. The most damaging consequence is that an illusion in one generation tends to become the private opinion of the next generation. One of the most important collective illusions we've ever discovered, has to do with the way that people define a successful life. It turns out that the vast majority of the American Public believes that most people in the country care about: Wealth, Status, Power. When in fact, the opposite is true. The vast majority of the American Public are focused on a more personal fulfillment orientation, but our kids are paying an incredible price because they do not understand that this is an illusion. They try to chase fame because they believe that's what other people will recognize as success. So, if we do nothing about collective illusions now, our silence will virtually guarantee that our children and our grandchildren will have this view as their private opinion. We've known about collective illusions for over a hundred years. And up until the last, say, 20 years, you could've probably counted on two hands and two feet the number of serious, societal, collective illusions that had existed. Since then, that number has exploded. They affect society as a whole, but we are all part of creating and sustaining the illusions. Even when we fundamentally end up disagreeing, a truthful disagreement is always better than a collective illusion. Being aware that collective illusions exist is the starting point. The only way to discover those is the same way that you actually dismantle them. You got to have conversations. You got to talk to each other. If you understand that fact, and you create the enabling conditions, that allow everyday people to reveal who they really are to each other, these illusions can crumble in a hurry, and social change can happen at a scale and pace that would otherwise seem unimaginable. This series is brought to you by Stand Together, a community of changemakers tackling our biggest challenges.",
#  'summary': "- Public opinion should reflect individual private opinion like a mirror\n- Collective illusions distort the relationship between private and public opinion\n- Collective illusions occur when people assume that others in a group hold an opinion that they don't actually hold\n- Collective illusions lead to decisions that are contrary to personal values and can be fatal to free society\n- Private opinion methods help reveal people's true views free of social pressure and other distorting influences\n- Collective illusions can be found in many areas of society\n- The most damaging consequence of collective illusions is that they can become the private opinion of the next generation\n- Wealth, status, and power are a collective illusion of what people believe is success\n- Collective illusions have increased in the last 2- years and everyone is part of creating and sustaining them\n- Conversations can help reveal collective illusions and enable social change to happen\n- This series is brought to you by Stand Together, a community of changemakers tackling our biggest challenges.",
#  '__index_level_0__': 0}

# %%
preprocess_function(custom_dataset[0]).keys()
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels'])

# %%
# create tokenize dataset
tokenized_custom_dataset = custom_dataset.map(preprocess_function, batched=True)
tokenized_custom_dataset = tokenized_custom_dataset.train_test_split(test_size=0.2)
# Out:
# Map:   0%|          | 0/4138 [00:00<?, ? examples/s]

# %% [markdown]
# # Evaluate

# %%
import evaluate
rouge = evaluate.load("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
import numpy as np

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)

    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# # Training

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
from transformers import DataCollatorForSeq2Seq
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

# %%
# !git config --global credential.helper store
from huggingface_hub import login
login('', add_to_git_credential=True)

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | bash
# !apt install git-lfs -y
# !git lfs install

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./BulletBriefT5",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=5,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=True,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_custom_dataset["train"],
    eval_dataset=tokenized_custom_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# /content/./BulletBriefT5 is already a clone of https://huggingface.co/Darakarn/BulletBriefT5. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/./BulletBriefT5 is already a clone of https://huggingface.co/Darakarn/BulletBriefT5. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='5175' max='5175' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5175/5175 30:24, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.905200</td>
#       <td>1.734827</td>
#       <td>0.144300</td>
#       <td>0.063700</td>
#       <td>0.118700</td>
#       <td>0.118700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.861300</td>
#       <td>1.717063</td>
#       <td>0.144400</td>
#       <td>0.064100</td>
#       <td>0.118800</td>
#       <td>0.119000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.857200</td>
#       <td>1.717640</td>
#       <td>0.143800</td>
#       <td>0.063600</td>
#       <td>0.118000</td>
#       <td>0.118100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.840700</td>
#       <td>1.712846</td>
#       <td>0.144200</td>
#       <td>0.064000</td>
#       <td>0.118500</td>
#       <td>0.118600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.836400</td>
#       <td>1.710687</td>
#       <td>0.144100</td>
#       <td>0.063900</td>
#       <td>0.118400</td>
#       <td>0.118500</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Several commits (21) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (21) will be pushed upstream.
# Several commits (22) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (22) will be pushed upstream.
# Several commits (23) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (23) will be pushed upstream.
# Several commits (24) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (24) will be pushed upstream.
# Several commits (25) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (25) will be pushed upstream.
# Several commits (26) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (26) will be pushed upstream.
# Several commits (27) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (27) will be pushed upstream.
# Several commits (28) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (28) will be pushed upstream.
# Several commits (29) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (29) will be pushed upstream.
# Several commits (30) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (30) will be pushed upstream.
# TrainOutput(global_step=5175, training_loss=1.8574653308518267, metrics={'train_runtime': 1824.8702, 'train_samples_per_second': 5.669, 'train_steps_per_second': 2.836, 'total_flos': 3431755795464192.0, 'train_loss': 1.8574653308518267, 'epoch': 5.0})
